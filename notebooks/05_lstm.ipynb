# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

# %%
import json
import numpy as np
from src.data_loader import load_raw_data
from src.preprocessing import clean_raw_data, chronological_split, fit_scaler, apply_scaler, inverse_transform_column
from src.feature_engineering import build_features
from src.sequence_builder import create_sequences_for_all_splits
from src.evaluation.metrics import evaluate_all
from src.config import MODEL_FEATURE_COLUMNS, TARGET_COL, DEFAULT_LOOKBACK, FORECAST_HORIZON

DEV_LOOKBACK = 72  # temporary, for fast iteration — NOT the final 168

df_raw = load_raw_data()
df_clean = clean_raw_data(df_raw)
df_features = build_features(df_clean)
splits = chronological_split(df_features)

scale_columns = MODEL_FEATURE_COLUMNS + [TARGET_COL]
scaler = fit_scaler(splits.train, scale_columns)

train_scaled = apply_scaler(splits.train, scaler, scale_columns)
val_scaled = apply_scaler(splits.val, scaler, scale_columns)
test_scaled = apply_scaler(splits.test, scaler, scale_columns)

sequences = create_sequences_for_all_splits(train_scaled, val_scaled, test_scaled, MODEL_FEATURE_COLUMNS)
X_train, y_train_scaled = sequences["train"]
X_val, y_val_scaled = sequences["val"]
X_test, y_test_scaled = sequences["test"]

print("Ready:", X_train.shape, X_val.shape, X_test.shape)
# Out:
# 2026-09-11 11:09:18 | INFO     | src.data_loader | Loading raw dataset from C:\Users\Ram\OneDrive\Desktop\energy-demand-lstm\data\raw\continuous_dataset.csv
# 2026-09-11 11:09:19 | INFO     | src.data_loader | Loaded raw dataset: 48048 rows, 17 columns
# 2026-09-11 11:09:19 | INFO     | src.preprocessing | Cleaning complete: 48048 rows, 4 flagged as diagnostic extreme events (|z| > 4.0)
# 2026-09-11 11:09:20 | INFO     | src.feature_engineering | Added national weather averages: temp_avg, humidity_avg, precip_avg, wind_avg
# 2026-09-11 11:09:20 | INFO     | src.feature_engineering | Added calendar features and cyclical encodings
# 2026-09-11 11:09:20 | INFO     | src.feature_engineering | Added lag features: ['lag_1', 'lag_24', 'lag_48', 'lag_168']
# 2026-09-11 11:09:20 | INFO     | src.feature_engineering | Added rolling features: rolling_mean_24, rolling_std_24, rolling_mean_168
# 2026-09-11 11:09:20 | INFO     | src.feature_engineering | Feature engineering complete: 48048 rows before, 47880 rows after dropping NaN warm-up rows (168 dropped, expected ~168)
# 2026-09-11 11:09:20 | INFO     | src.preprocessing | Chronological split: train=33516 (2015-01-10 01:00:00 to 2018-11-06 12:00:00), val=7182 (2018-11-06 13:00:00 to 2019-09-01 18:00:00), test=7182 (2019-09-01 19:00:00 to 2020-06-27 00:00:00)
# 2026-09-11 11:09:21 | INFO     | src.preprocessing | Scaler fit on training data: 21 columns, 33516 rows
# 2026-09-11 11:09:22 | INFO     | src.sequence_builder | Built 33421 sequences: X=(33421, 72, 20), y=(33421, 24) (lookback=72, horizon=24, dropped 95 boundary rows)
# 2026-09-11 11:09:22 | INFO     | src.sequence_builder | Split 'train': X=(33421, 72, 20), y=(33421, 24)
# 2026-09-11 11:09:22 | INFO     | src.sequence_builder | Built 7087 sequences: X=(7087, 72, 20), y=(7087, 24) (lookback=72, horizon=24, dropped 95 boundary rows)
# 2026-09-11 11:09:22 | INFO     | src.sequence_builder | Split 'val': X=(7087, 72, 20), y=(7087, 24)
# 2026-09-11 11:09:22 | INFO     | src.sequence_builder | Built 7087 sequences: X=(7087, 72, 20), y=(7087, 24) (lookback=72, horizon=24, dropped 95 boundary rows)
# 2026-09-11 11:09:22 | INFO     | src.sequence_builder | Split 'test': X=(7087, 72, 20), y=(7087, 24)
# Ready: (33421, 72, 20) (7087, 72, 20) (7087, 72, 20)

# %%
import os
import torch
torch.set_num_threads(os.cpu_count())

from src.models.lstm import LSTMForecaster
from src.training.trainer import train_model, predict

num_features = X_train.shape[2]
print("X_train shape:", X_train.shape)

lstm_model = LSTMForecaster(num_features=num_features)

# Quick peek at the cell state's existence
sample_out, (h_n, c_n) = lstm_model.lstm(torch.from_numpy(X_train[:2]).float())
print("Hidden state shape:", h_n.shape, "| Cell state shape:", c_n.shape)

history = train_model(lstm_model, X_train, y_train_scaled, X_val, y_val_scaled, epochs=15)
print("Epochs trained:", history["epochs_trained"])
print("Parameters:", history["num_parameters"])
print("Training time (s):", round(history["training_time_seconds"], 1))
# Out:
# X_train shape: (33421, 72, 20)
# Hidden state shape: torch.Size([1, 2, 64]) | Cell state shape: torch.Size([1, 2, 64])
# 2026-09-11 11:09:40 | INFO     | src.training.trainer | Training LSTMForecaster | 23576 parameters | device=cpu
# 2026-09-11 11:09:40 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 11:10:08 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 11:10:22 | INFO     | src.training.trainer | Epoch 1/15 | train_loss=0.057399 | val_loss=0.018518
# 2026-09-11 11:10:22 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 11:10:48 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 11:11:00 | INFO     | src.training.trainer | Epoch 2/15 | train_loss=0.008424 | val_loss=0.007244
# 2026-09-11 11:11:00 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 13:11:18 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 13:11:34 | INFO     | src.training.trainer | Epoch 3/15 | train_loss=0.004503 | val_loss=0.005620
# 2026-09-11 13:11:34 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 13:12:10 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 13:13:01 | INFO     | src.training.trainer | Epoch 4/15 | train_loss=0.003388 | val_loss=0.004178
# 2026-09-11 13:13:01 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 13:13:39 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 13:13:52 | INFO     | src.training.trainer | Epoch 5/15 | train_loss=0.002785 | val_loss=0.003600
# 2026-09-11 13:13:52 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 13:14:18 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 13:14:27 | INFO     | src.training.trainer | Epoch 6/15 | train_loss=0.002472 | val_loss=0.003575
# 2026-09-11 13:14:27 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 13:14:46 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 13:14:54 | INFO     | src.training.trainer | Epoch 7/15 | train_loss=0.002270 | val_loss=0.003018
# 2026-09-11 13:14:54 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 13:15:17 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 13:15:27 | INFO     | src.training.trainer | Epoch 8/15 | train_loss=0.002146 | val_loss=0.003089
# 2026-09-11 13:15:27 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 13:16:25 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 13:16:38 | INFO     | src.training.trainer | Epoch 9/15 | train_loss=0.002026 | val_loss=0.002741
# 2026-09-11 13:16:38 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 13:17:01 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 13:17:10 | INFO     | src.training.trainer | Epoch 10/15 | train_loss=0.001936 | val_loss=0.002659
# 2026-09-11 13:17:10 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 13:17:56 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 13:18:13 | INFO     | src.training.trainer | Epoch 11/15 | train_loss=0.001877 | val_loss=0.002629
# 2026-09-11 13:18:13 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 15:18:08 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 15:18:30 | INFO     | src.training.trainer | Epoch 12/15 | train_loss=0.001793 | val_loss=0.002701
# 2026-09-11 15:18:30 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 15:19:04 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 15:19:27 | INFO     | src.training.trainer | Epoch 13/15 | train_loss=0.001749 | val_loss=0.002719
# 2026-09-11 15:19:27 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 15:20:22 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 15:20:35 | INFO     | src.training.trainer | Epoch 14/15 | train_loss=0.001725 | val_loss=0.002617
# 2026-09-11 15:20:35 | INFO     | src.training.trainer |   batch 0/131
# 2026-09-11 15:21:00 | INFO     | src.training.trainer |   batch 100/131
# 2026-09-11 15:21:12 | INFO     | src.training.trainer | Epoch 15/15 | train_loss=0.001677 | val_loss=0.002419
# 2026-09-11 15:21:12 | INFO     | src.training.trainer | Training complete: 15091.6s, 15 epochs, 23576 parameters
# Epochs trained: 15
# Parameters: 23576
# Training time (s): 15091.6

# %%
y_pred_test_scaled = predict(lstm_model, X_test)
y_true_lstm = inverse_transform_column(y_test_scaled, scaler, scale_columns, TARGET_COL)
y_pred_lstm = inverse_transform_column(y_pred_test_scaled, scaler, scale_columns, TARGET_COL)

lstm_metrics = evaluate_all(y_true_lstm, y_pred_lstm)
print("LSTM:", lstm_metrics)
# Out:
# LSTM: {'MAE': 67.42262438218985, 'RMSE': 93.76762669559268, 'MAPE': 5.773967504668753, 'sMAPE': 5.65469946598041, 'R2': 0.7420732922848885}

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(history["train_loss"], label="Train Loss")
ax.plot(history["val_loss"], label="Validation Loss")
ax.set_xlabel("Epoch")
ax.set_ylabel("MSE Loss (scaled)")
ax.set_title("LSTM Training History")
ax.legend()
plt.show()

# %%
import json
from pathlib import Path

experiments_path = Path.cwd().parent / "experiments" / "model_comparison.json"
with open(experiments_path) as f:
    all_results = json.load(f)

all_results["LSTM"] = {
    **lstm_metrics,
    "training_time_seconds": history["training_time_seconds"],
    "num_parameters": history["num_parameters"],
}

with open(experiments_path, "w") as f:
    json.dump(all_results, f, indent=2)

print("Updated experiments/model_comparison.json with LSTM results")
# Out:
# Updated experiments/model_comparison.json with LSTM results
